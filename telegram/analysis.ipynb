# %%
import json
import pandas as pd
import matplotlib.pyplot as plt


with open('output.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

data = list(data.values())
print(data)
df = pd.DataFrame(data)
print(df)
print(f'Всего сообщений: {len(df)}')
# Out:
# [{'user': 'user_a', 'text': 'доброе утро'}, {'user': 'user_b', 'text': 'привет, как дела'}, {'user': 'user_a', 'text': 'всё хорошо, работаю над задачей'}, {'user': 'user_c', 'text': 'кто сегодня на связи'}, {'user': 'user_b', 'text': 'я буду через час'}, {'user': 'user_a', 'text': 'договорились, ждём'}, {'user': 'user_d', 'text': 'скиньте ссылку на документ'}, {'user': 'user_c', 'text': 'сейчас отправлю в чат'}, {'user': 'user_b', 'text': 'готово, проверил отчёт'}, {'user': 'user_a', 'text': 'отлично, спасибо за помощь'}, {'user': 'user_d', 'text': 'какие планы на выходные'}, {'user': 'user_c', 'text': 'думаю поработать над презентацией'}, {'user': 'user_b', 'text': 'я доделал макет'}, {'user': 'user_a', 'text': 'скинь посмотреть'}, {'user': 'user_d', 'text': 'хорошая идея'}, {'user': 'user_c', 'text': 'созвон сегодня в 18:00'}, {'user': 'user_b', 'text': 'буду'}, {'user': 'user_a', 'text': 'я тоже подключусь'}, {'user': 'user_d', 'text': 'договорились'}, {'user': 'user_c', 'text': 'до встречи вечером'}, {'user': 'user_a', 'text': 'кстати, я нашёл ошибку в коде'}, {'user': 'user_b', 'text': 'что за ошибка'}, {'user': 'user_a', 'text': 'в функции расчёта данных'}, {'user': 'user_c', 'text': 'покажи скриншот'}, {'user': 'user_d', 'text': 'интересно посмотреть'}, {'user': 'user_b', 'text': 'да, скинь в чат'}, {'user': 'user_a', 'text': 'сейчас скину'}, {'user': 'user_c', 'text': 'вижу проблему'}, {'user': 'user_b', 'text': 'там индекс неверный'}, {'user': 'user_d', 'text': 'надо поправить в двух местах'}, {'user': 'user_a', 'text': 'исправил, проверьте'}, {'user': 'user_c', 'text': 'теперь работает'}, {'user': 'user_b', 'text': 'отлично, спасибо'}, {'user': 'user_d', 'text': 'команда молодцы'}, {'user': 'user_a', 'text': 'завтра продолжаем'}, {'user': 'user_c', 'text': 'во сколько начнём'}, {'user': 'user_b', 'text': 'в 10 утра'}, {'user': 'user_d', 'text': 'мне удобно'}, {'user': 'user_a', 'text': 'договорились, в 10'}, {'user': 'user_c', 'text': 'спокойной ночи'}, {'user': 'user_b', 'text': 'до завтра'}, {'user': 'user_d', 'text': 'всем пока'}, {'user': 'user_a', 'text': 'доброе утро, я на месте'}, {'user': 'user_c', 'text': 'я тоже готов'}, {'user': 'user_b', 'text': 'начнём с отчёта'}, {'user': 'user_d', 'text': 'у меня готовы данные'}, {'user': 'user_a', 'text': 'отправляй'}, {'user': 'user_c', 'text': 'загрузил файл'}, {'user': 'user_b', 'text': 'посмотрел, всё верно'}, {'user': 'user_d', 'text': 'тогда переходим к следующей задаче'}, {'user': 'user_a', 'text': 'что по срокам'}, {'user': 'user_c', 'text': 'до пятницы'}, {'user': 'user_b', 'text': 'успеваем'}, {'user': 'user_d', 'text': 'я возьму первую часть'}, {'user': 'user_a', 'text': 'я вторую'}, {'user': 'user_c', 'text': 'тогда я третью'}, {'user': 'user_b', 'text': 'распределили отлично'}, {'user': 'user_d', 'text': 'работаем'}, {'user': 'user_a', 'text': 'вопрос по данным'}, {'user': 'user_c', 'text': 'слушаю'}, {'user': 'user_b', 'text': 'какой формат'}, {'user': 'user_d', 'text': 'json подойдёт'}, {'user': 'user_a', 'text': 'ок, сделаю'}, {'user': 'user_c', 'text': 'обед через 30 минут'}, {'user': 'user_b', 'text': 'давайте вместе закажем'}, {'user': 'user_d', 'text': 'я за'}, {'user': 'user_a', 'text': 'тоже'}, {'user': 'user_c', 'text': 'тогда в 13:00'}, {'user': 'user_b', 'text': 'что берём'}, {'user': 'user_d', 'text': 'предлагаю пиццу'}, {'user': 'user_a', 'text': 'отличный выбор'}, {'user': 'user_c', 'text': 'согласен'}, {'user': 'user_b', 'text': 'я закажу'}, {'user': 'user_d', 'text': 'скиньте предпочтения'}, {'user': 'user_a', 'text': 'мне с грибами'}, {'user': 'user_c', 'text': 'мне пепперони'}, {'user': 'user_b', 'text': 'записал'}, {'user': 'user_d', 'text': 'ждём доставку'}, {'user': 'user_a', 'text': 'пока работаю над задачей'}, {'user': 'user_c', 'text': 'я тоже'}, {'user': 'user_b', 'text': 'пицца через 20 минут'}, {'user': 'user_d', 'text': 'супер'}, {'user': 'user_a', 'text': 'перерыв на обед'}, {'user': 'user_c', 'text': 'вкусно'}, {'user': 'use ...
#       user                             text
# 0   user_a                      доброе утро
# 1   user_b                 привет, как дела
# 2   user_a  всё хорошо, работаю над задачей
# 3   user_c             кто сегодня на связи
# 4   user_b                 я буду через час
# ..     ...                              ...
# 95  user_c                  принял, собираю
# 96  user_b                           готово
# 97  user_d             проверил, ошибок нет
# 98  user_a                  отличная работа
# 99  user_c          всем спасибо, до завтра
#
# [100 rows x 2 columns]
# Всего сообщений: 100

# %%
top_users = df['user'].value_counts().head(10)

plt.figure(figsize=(10, 5))
top_users.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Топ участников по количеству сообщений', fontsize=14)
plt.xlabel('Участник')
plt.ylabel('Количество сообщений')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

df['msg_len'] = df['text'].apply(len)

# %%
avg_len = df.groupby('user')['msg_len'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
avg_len.plot(kind='barh', color='lightcoral', edgecolor='black')
plt.title('Средняя длина сообщения по участникам', fontsize=14)
plt.xlabel('Средняя длина (количество символов)')
plt.ylabel('Участник')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
print('Общая статистика чата:')
print(f'Всего сообщений: {len(df)}')
print(f'Участников: {df['user'].nunique()}')
print(f'Средняя длина сообщения: {df['msg_len'].mean():.1f} символов')
print(f'Минимальная длина: {df['msg_len'].min()} символов')
print(f'Максимальная длина: {df['msg_len'].max()} символов')
print(f'Медианная длина: {df['msg_len'].median():.0f} символов')
# Out:
# Общая статистика чата:
# Всего сообщений: 100
# Участников: 4
# Средняя длина сообщения: 15.7 символов
# Минимальная длина: 4 символов
# Максимальная длина: 34 символов
# Медианная длина: 15 символов
